# %%
import pandas as pd

# %%
magic_data = pd.read_csv("../MagicDatasets/Magic_Combined_DF")

# %%
magic_data2 = pd.read_csv("../MagicDatasets/Magic_Pandas_DF")
# Out:
# /Users/KVASU/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
magic_data2.iloc[:,9:18]
# Out:
#                       imageName  layout  life  loyalty   manaCost  \
# 0             ancestor's chosen  normal   NaN      NaN  {5}{W}{W}
# 1                angel of mercy  normal   NaN      NaN     {4}{W}
# 2              angelic blessing  normal   NaN      NaN     {2}{W}
# 3                angelic chorus  normal   NaN      NaN  {3}{W}{W}
# 4                  angelic wall  normal   NaN      NaN     {1}{W}
# 5               aura of silence  normal   NaN      NaN  {1}{W}{W}
# 6              aven cloudchaser  normal   NaN      NaN     {3}{W}
# 7                ballista squad  normal   NaN      NaN     {3}{W}
# 8                       bandage  normal   NaN      NaN        {W}
# 9         beacon of immortality  normal   NaN      NaN     {5}{W}
# 10              benalish knight  normal   NaN      NaN     {2}{W}
# 11     cho-manno, revolutionary  normal   NaN      NaN  {2}{W}{W}
# 12                      condemn  normal   NaN      NaN        {W}
# ...

# %%
mask = magic_data2.imageName.str.contains("An", case=False)
magic_data2.loc[mask, "imageName"][:100].tolist()
# Out:
# ["ancestor's chosen",
#  'angel of mercy',
#  'angelic blessing',
#  'angelic chorus',
#  'angelic wall',
#  'bandage',
#  'cho-manno, revolutionary',
#  'glorious anthem',
#  'icatian priest',
#  'kjeldoran royal guard',
#  'serra angel',
#  'arcanis the omnipotent',
#  'boomerang',
#  'cancel',
#  'phantom warrior',
#  'rootwater commando',
#  'ascendant evincar',
#  'doomed necromancer',
#  'nantuko husk',
#  'phyrexian rager',
#  'anaba bodyguard',
#  'arcane teachings',
#  'bogardan firefiend',
#  'fists of the anvil',
#  'goblin elite infantry',
#  'hill giant',
#  'manabarbs',
#  'mogg fanatic',
#  'prodigal pyromancer',
#  'shivan dragon',
#  'shivan hellkite',
#  'siege-gang commander',
#  'thundering giant',
#  'uncontrollable anger',
#  'viashino sandscout',
#  'abundance',
#  'blanchwood armor',
#  'canopy spider',
#  'giant growth',
#  'giant spider',
#  'hurricane',
#  'karplusan strider',
#  'llanowar elves',
#  'llanowar sentinel',
#  'rampant growth',
# ...

# %%
zip(items, items)
# Out:
# [("ancestor's chosen", "ancestor's chosen"),
#  ('angel of mercy', 'angel of mercy'),
#  ('angelic blessing', 'angelic blessing'),
#  ('angelic chorus', 'angelic chorus'),
#  ('angelic wall', 'angelic wall'),
#  ('aura of silence', 'aura of silence'),
#  ('aven cloudchaser', 'aven cloudchaser'),
#  ('ballista squad', 'ballista squad'),
#  ('bandage', 'bandage'),
#  ('beacon of immortality', 'beacon of immortality'),
#  ('benalish knight', 'benalish knight'),
#  ('cho-manno, revolutionary', 'cho-manno, revolutionary'),
#  ('condemn', 'condemn'),
#  ('demystify', 'demystify'),
#  ('field marshal', 'field marshal'),
#  ('ghost warden', 'ghost warden'),
#  ('glorious anthem', 'glorious anthem'),
#  ('hail of arrows', 'hail of arrows'),
#  ('heart of light', 'heart of light'),
#  ('high ground', 'high ground'),
#  ('holy day', 'holy day'),
#  ('holy strength', 'holy strength'),
#  ('honor guard', 'honor guard'),
#  ('icatian priest', 'icatian priest'),
# ...

# %%
def get_namelist(data):
    items = data.iloc[:,9]
    name_list = zip(items,items)
    return name_list

# %%
get_namelist(magic_data2)
# Out:
# [("ancestor's chosen", "ancestor's chosen"),
#  ('angel of mercy', 'angel of mercy'),
#  ('angelic blessing', 'angelic blessing'),
#  ('angelic chorus', 'angelic chorus'),
#  ('angelic wall', 'angelic wall'),
#  ('aura of silence', 'aura of silence'),
#  ('aven cloudchaser', 'aven cloudchaser'),
#  ('ballista squad', 'ballista squad'),
#  ('bandage', 'bandage'),
#  ('beacon of immortality', 'beacon of immortality'),
#  ('benalish knight', 'benalish knight'),
#  ('cho-manno, revolutionary', 'cho-manno, revolutionary'),
#  ('condemn', 'condemn'),
#  ('demystify', 'demystify'),
#  ('field marshal', 'field marshal'),
#  ('ghost warden', 'ghost warden'),
#  ('glorious anthem', 'glorious anthem'),
#  ('hail of arrows', 'hail of arrows'),
#  ('heart of light', 'heart of light'),
#  ('high ground', 'high ground'),
#  ('holy day', 'holy day'),
#  ('holy strength', 'holy strength'),
#  ('honor guard', 'honor guard'),
#  ('icatian priest', 'icatian priest'),
# ...
