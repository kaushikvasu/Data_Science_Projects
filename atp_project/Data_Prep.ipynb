# %%
import pandas as pd

# %%
atp_2009 = pd.read_csv('data/atp_matches_2009.csv')
atp_2010 = pd.read_csv('data/atp_matches_2010.csv')
atp_2011 = pd.read_csv('data/atp_matches_2011.csv')
atp_2012 = pd.read_csv('data/atp_matches_2012.csv')
atp_2013 = pd.read_csv('data/atp_matches_2013.csv')
atp_2014 = pd.read_csv('data/atp_matches_2014.csv')
atp_2015 = pd.read_csv('data/atp_matches_2015.csv')
atp_2016 = pd.read_csv('data/atp_matches_2016.csv')
atp_2017 = pd.read_csv('data/atp_matches_2017.csv')
atp_2018 = pd.read_csv('data/atp_matches_2018.csv')

# %%
list_of_df = [atp_2009, atp_2010, atp_2011, atp_2012, atp_2013, atp_2014, atp_2015, atp_2016, atp_2017, atp_2018]

# %%
for i in list_of_df:
    if i.columns.all() == atp_2009.columns.all():
        print ('Same Columns')
    else:
        print ('Different Columns')
# Out:
# Same Columns
# Same Columns
# Same Columns
# Same Columns
# Same Columns
# Same Columns
# Same Columns
# Same Columns
# Same Columns
# Same Columns

# %%
for i in list_of_df:
    print (len(i))
# Out:
# 3074
# 3058
# 3030
# 3025
# 2959
# 2901
# 2958
# 3004
# 2886
# 2494

# %%
atp_10_years = pd.concat(list_of_df)

# %%
atp_10_years
# Out:
#                            tourney_id                 tourney_name surface  \
# 0                            2009-329                        Tokyo    Hard
# 1                            2009-329                        Tokyo    Hard
# 2                            2009-329                        Tokyo    Hard
# 3                            2009-329                        Tokyo    Hard
# 4                            2009-329                        Tokyo    Hard
# 5                            2009-329                        Tokyo    Hard
# 6                            2009-329                        Tokyo    Hard
# 7                            2009-329                        Tokyo    Hard
# 8                            2009-329                        Tokyo    Hard
# 9                            2009-329                        Tokyo    Hard
# 10                           2009-329                        Tokyo    Hard
# ...

# %%
atp_10_years = atp_10_years.reset_index().iloc[:,1:]

# %%
atp_10_years
# Out:
#                             tourney_id                 tourney_name surface  \
# 0                             2009-329                        Tokyo    Hard
# 1                             2009-329                        Tokyo    Hard
# 2                             2009-329                        Tokyo    Hard
# 3                             2009-329                        Tokyo    Hard
# 4                             2009-329                        Tokyo    Hard
# 5                             2009-329                        Tokyo    Hard
# 6                             2009-329                        Tokyo    Hard
# 7                             2009-329                        Tokyo    Hard
# 8                             2009-329                        Tokyo    Hard
# 9                             2009-329                        Tokyo    Hard
# 10                            2009-329                        Tokyo    Hard
# ...

# %%
atp_10_years.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced'],
#       dtype='object')

# %%
cols_to_keep = [
#                 'tourney_id', 
                'tourney_name', 
                'surface', 
                'draw_size', 
                'tourney_level',
#                 'tourney_date', 
#                 'match_num', 
#                 'winner_id', 
                'winner_seed', 
                'winner_entry',
                'winner_name', 
                'winner_hand', 
                'winner_ht', 
                'winner_ioc', 
                'winner_age',
                'winner_rank', 
                'winner_rank_points', 
#                 'loser_id', 
                'loser_seed',
                'loser_entry', 
                'loser_name', 
                'loser_hand', 
                'loser_ht', 
                'loser_ioc',
                'loser_age', 
                'loser_rank', 
                'loser_rank_points', 
#                 'score', 
                'best_of',
                'round' 
#                 'minutes', 
#                 'w_ace', 
#                 'w_df', 
#                 'w_svpt', 
#                 'w_1stIn', 
#                 'w_1stWon',
#                 'w_2ndWon', 
#                 'w_SvGms', 
#                 'w_bpSaved', 
#                 'w_bpFaced', 
#                 'l_ace', 
#                 'l_df',
#                 'l_svpt', 
#                 'l_1stIn', 
#                 'l_1stWon', 
#                 'l_2ndWon', 
#                 'l_SvGms', 
#                 'l_bpSaved',
#                 'l_bpFaced'
]

# %%
atp_trim = atp_10_years[cols_to_keep]

# %%
atp_trim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29389 entries, 0 to 29388
# Data columns (total 24 columns):
# tourney_name          29326 non-null object
# surface               29208 non-null object
# draw_size             29326 non-null float64
# tourney_level         29326 non-null object
# winner_seed           12754 non-null float64
# winner_entry          3441 non-null object
# winner_name           29326 non-null object
# winner_hand           29310 non-null object
# winner_ht             25465 non-null float64
# winner_ioc            29326 non-null object
# winner_age            29316 non-null float64
# winner_rank           29111 non-null float64
# winner_rank_points    29111 non-null float64
# loser_seed            6876 non-null float64
# loser_entry           5778 non-null object
# loser_name            29326 non-null object
# loser_hand            29283 non-null object
# loser_ht              23688 non-null float64
# loser_ioc             29326 non-null object
# ...

# %%
atp_trim2 = atp_trim
# atp_trim2['Player1_id'] = 0
# atp_trim2['Player1_seed'] = 0
# atp_trim2['Player1_entry'] = 0
# atp_trim2['Player1_name'] = 0
# atp_trim2['Player1_hand'] = 0
# atp_trim2['Player1_ht'] = 0
# atp_trim2['Player1_ioc'] = 0
# atp_trim2['Player1_age'] = 0
# atp_trim2['Player1_rank'] = 0
# atp_trim2['Player1_rank_points'] = 0
# atp_trim2['Player2_id'] = 0
# atp_trim2['Player2_seed'] = 0
# atp_trim2['Player2_entry'] = 0
# atp_trim2['Player2_name'] = 0
# atp_trim2['Player2_hand'] = 0
# atp_trim2['Player2_ht'] = 0
# atp_trim2['Player2_ioc'] = 0
# atp_trim2['Player2_age'] = 0
# atp_trim2['Player2_rank'] = 0
# atp_trim2['Player2_rank_points'] = 0
# atp_trim2['winner'] = 0

# %%
atp_trim2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29389 entries, 0 to 29388
# Data columns (total 24 columns):
# tourney_name          29326 non-null object
# surface               29208 non-null object
# draw_size             29326 non-null float64
# tourney_level         29326 non-null object
# winner_seed           12754 non-null float64
# winner_entry          3441 non-null object
# winner_name           29326 non-null object
# winner_hand           29310 non-null object
# winner_ht             25465 non-null float64
# winner_ioc            29326 non-null object
# winner_age            29316 non-null float64
# winner_rank           29111 non-null float64
# winner_rank_points    29111 non-null float64
# loser_seed            6876 non-null float64
# loser_entry           5778 non-null object
# loser_name            29326 non-null object
# loser_hand            29283 non-null object
# loser_ht              23688 non-null float64
# loser_ioc             29326 non-null object
# ...

# %%
atp_trim2.groupby('winner_rank').count()
# Out:
#              tourney_name  surface  draw_size  tourney_level  winner_seed  \
# winner_rank
# 1.0                   646      646        646            646          621
# 2.0                   604      604        604            604          574
# 3.0                   540      539        540            540          517
# 4.0                   482      482        482            482          461
# 5.0                   509      509        509            509          479
# 6.0                   472      470        472            472          445
# 7.0                   472      470        472            472          443
# 8.0                   472      471        472            472          454
# 9.0                   406      405        406            406          391
# 10.0                  391      390        391            391          379
# 11.0                  386      386        386            386          367
# ...

# %%
atp_trim2.iloc[0,1]
# Out:
# 'Hard'

# %%
atp_higher_ranked_winner = atp_trim2[atp_trim2['winner_rank'] < atp_trim2['loser_rank']]
atp_lower_ranked_winner = atp_trim2[atp_trim2['winner_rank'] > atp_trim2['loser_rank']]
atp_same_ranked_winner = atp_trim2[atp_trim2['winner_rank'] == atp_trim2['loser_rank']]

# %%
atp_same_ranked_winner
# Out:
# Empty DataFrame
# Columns: [tourney_name, surface, draw_size, tourney_level, winner_seed, winner_entry, winner_name, winner_hand, winner_ht, winner_ioc, winner_age, winner_rank, winner_rank_points, loser_seed, loser_entry, loser_name, loser_hand, loser_ht, loser_ioc, loser_age, loser_rank, loser_rank_points, best_of, round]
# Index: []
#
# [0 rows x 24 columns]

# %%
atp_higher_ranked_winner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19217 entries, 1 to 29388
# Data columns (total 24 columns):
# tourney_name          19217 non-null object
# surface               19148 non-null object
# draw_size             19217 non-null float64
# tourney_level         19217 non-null object
# winner_seed           11673 non-null float64
# winner_entry          664 non-null object
# winner_name           19217 non-null object
# winner_hand           19216 non-null object
# winner_ht             17541 non-null float64
# winner_ioc            19217 non-null object
# winner_age            19217 non-null float64
# winner_rank           19217 non-null float64
# winner_rank_points    19217 non-null float64
# loser_seed            2153 non-null float64
# loser_entry           5278 non-null object
# loser_name            19217 non-null object
# loser_hand            19212 non-null object
# loser_ht              15169 non-null float64
# loser_ioc             19217 non-null object
# ...

# %%
atp_lower_ranked_winner.columns
# Out:
# Index(['tourney_name', 'surface', 'draw_size', 'tourney_level', 'winner_seed',
#        'winner_entry', 'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc',
#        'winner_age', 'winner_rank', 'winner_rank_points', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'best_of', 'round'],
#       dtype='object')

# %%
winner_dict = {'winner_seed' : 'player1_seed', 
               'winner_entry' : 'player1_entry', 
               'winner_name' : 'player1_name',
               'winner_hand' : 'player1_hand', 
               'winner_ht' : 'player1_ht', 
               'winner_ioc' : 'player1_ioc', 
               'winner_age' : 'player1_age', 
               'winner_rank' : 'player1_rank',
               'winner_rank_points' : 'player1_rank_points', 
               'loser_seed' : 'player2_seed', 
               'loser_entry' : 'player2_entry', 
               'loser_name' : 'player2_name',
               'loser_hand' : 'player2_hand', 
               'loser_ht' : 'player2_ht', 
               'loser_ioc' : 'player2_ioc', 
               'loser_age' : 'player2_age', 
               'loser_rank' : 'player2_rank',
               'loser_rank_points' : 'player2_rank_points'}

# %%
loser_dict = {'winner_seed' : 'player2_seed', 
               'winner_entry' : 'player2_entry', 
               'winner_name' : 'player2_name',
               'winner_hand' : 'player2_hand', 
               'winner_ht' : 'player2_ht', 
               'winner_ioc' : 'player2_ioc', 
               'winner_age' : 'player2_age', 
               'winner_rank' : 'player2_rank',
               'winner_rank_points' : 'player2_rank_points', 
               'loser_seed' : 'player1_seed', 
               'loser_entry' : 'player1_entry', 
               'loser_name' : 'player1_name',
               'loser_hand' : 'player1_hand', 
               'loser_ht' : 'player1_ht', 
               'loser_ioc' : 'player1_ioc', 
               'loser_age' : 'player1_age', 
               'loser_rank' : 'player1_rank',
               'loser_rank_points' : 'player1_rank_points'}

# %%
atp_higher_ranked_winner = atp_higher_ranked_winner.rename(index=str, columns=winner_dict)

# %%
atp_lower_ranked_winner = atp_lower_ranked_winner.rename(index=str, columns=loser_dict)

# %%
atp_higher_ranked_winner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19217 entries, 1 to 29388
# Data columns (total 24 columns):
# tourney_name           19217 non-null object
# surface                19148 non-null object
# draw_size              19217 non-null float64
# tourney_level          19217 non-null object
# player1_seed           11673 non-null float64
# player1_entry          664 non-null object
# player1_name           19217 non-null object
# player1_hand           19216 non-null object
# player1_ht             17541 non-null float64
# player1_ioc            19217 non-null object
# player1_age            19217 non-null float64
# player1_rank           19217 non-null float64
# player1_rank_points    19217 non-null float64
# player2_seed           2153 non-null float64
# player2_entry          5278 non-null object
# player2_name           19217 non-null object
# player2_hand           19212 non-null object
# player2_ht             15169 non-null float64
# ...

# %%
atp_lower_ranked_winner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9431 entries, 0 to 29385
# Data columns (total 24 columns):
# tourney_name           9431 non-null object
# surface                9404 non-null object
# draw_size              9431 non-null float64
# tourney_level          9431 non-null object
# player2_seed           1064 non-null float64
# player2_entry          2758 non-null object
# player2_name           9431 non-null object
# player2_hand           9428 non-null object
# player2_ht             7703 non-null float64
# player2_ioc            9431 non-null object
# player2_age            9428 non-null float64
# player2_rank           9431 non-null float64
# player2_rank_points    9431 non-null float64
# player1_seed           4723 non-null float64
# player1_entry          451 non-null object
# player1_name           9431 non-null object
# player1_hand           9431 non-null object
# player1_ht             8425 non-null float64
# player1_ioc            9431 non-null object
# ...

# %%
atp_higher_ranked_winner['winner'] = 1
atp_lower_ranked_winner['winner'] = 0

# %%
if atp_higher_ranked_winner.columns.all() == atp_lower_ranked_winner.columns.all():
    print ('Same Columns')
else:
    print ('Different Columns')
# Out:
# Same Columns

# %%
atp_higher_ranked_winner.columns
# Out:
# Index(['tourney_name', 'surface', 'draw_size', 'tourney_level', 'player1_seed',
#        'player1_entry', 'player1_name', 'player1_hand', 'player1_ht',
#        'player1_ioc', 'player1_age', 'player1_rank', 'player1_rank_points',
#        'player2_seed', 'player2_entry', 'player2_name', 'player2_hand',
#        'player2_ht', 'player2_ioc', 'player2_age', 'player2_rank',
#        'player2_rank_points', 'best_of', 'round', 'winner'],
#       dtype='object')

# %%
atp_higher_ranked_winner = atp_higher_ranked_winner[['tourney_name', 'surface', 'draw_size', 'tourney_level',
       'player1_seed', 'player1_entry', 'player1_name',
       'player1_hand', 'player1_ht', 'player1_ioc', 'player1_age',
       'player1_rank', 'player1_rank_points', 'player2_seed',
       'player2_entry', 'player2_name', 'player2_hand', 'player2_ht',
       'player2_ioc', 'player2_age', 'player2_rank', 'player2_rank_points',
       'best_of', 'round', 'winner']]

# %%
atp_lower_ranked_winner = atp_lower_ranked_winner[['tourney_name', 'surface', 'draw_size', 'tourney_level',
       'player1_seed', 'player1_entry', 'player1_name',
       'player1_hand', 'player1_ht', 'player1_ioc', 'player1_age',
       'player1_rank', 'player1_rank_points', 'player2_seed',
       'player2_entry', 'player2_name', 'player2_hand', 'player2_ht',
       'player2_ioc', 'player2_age', 'player2_rank', 'player2_rank_points',
       'best_of', 'round', 'winner']]

# %%
new_join = pd.concat([atp_higher_ranked_winner, atp_lower_ranked_winner])

# %%
new_join
# Out:
#                       tourney_name surface  draw_size tourney_level  \
# 1                            Tokyo    Hard       32.0             A
# 2                            Tokyo    Hard       32.0             A
# 3                            Tokyo    Hard       32.0             A
# 4                            Tokyo    Hard       32.0             A
# 5                            Tokyo    Hard       32.0             A
# 6                            Tokyo    Hard       32.0             A
# 7                            Tokyo    Hard       32.0             A
# 8                            Tokyo    Hard       32.0             A
# 11                           Tokyo    Hard       32.0             A
# 13                           Tokyo    Hard       32.0             A
# 15                           Tokyo    Hard       32.0             A
# 17                           Tokyo    Hard       32.0             A
# 19                           Tokyo    Hard       32.0             A
# ...

# %%
new_join.groupby('winner').count()
# Out:
#         tourney_name  surface  draw_size  tourney_level  player1_seed  \
# winner
# 0               9431     9404       9431           9431          4723
# 1              19217    19148      19217          19217         11673
#
#         player1_entry  player1_name  player1_hand  player1_ht  player1_ioc  \
# winner
# 0                 451          9431          9431        8425         9431
# 1                 664         19217         19216       17541        19217
#
#         ...    player2_entry  player2_name  player2_hand  player2_ht  \
# winner  ...
# 0       ...             2758          9431          9428        7703
# 1       ...             5278         19217         19212       15169
#
#         player2_ioc  player2_age  player2_rank  player2_rank_points  best_of  \
# winner
# 0              9431         9428          9431                 9431     9431
# 1             19217        19206         19217                19217    19217
#
#         round
# winner
# 0        9431
# ...

# %%
new_join
# Out:
#                       tourney_name surface  draw_size tourney_level  \
# 1                            Tokyo    Hard       32.0             A
# 2                            Tokyo    Hard       32.0             A
# 3                            Tokyo    Hard       32.0             A
# 4                            Tokyo    Hard       32.0             A
# 5                            Tokyo    Hard       32.0             A
# 6                            Tokyo    Hard       32.0             A
# 7                            Tokyo    Hard       32.0             A
# 8                            Tokyo    Hard       32.0             A
# 11                           Tokyo    Hard       32.0             A
# 13                           Tokyo    Hard       32.0             A
# 15                           Tokyo    Hard       32.0             A
# 17                           Tokyo    Hard       32.0             A
# 19                           Tokyo    Hard       32.0             A
# ...

# %%
# !pip install category_encoders

# %%
import sklearn
import category_encoders as ce
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
X = new_join.drop(columns='winner')
y = new_join['winner'].copy()

# %%
ohe = ce.OneHotEncoder(handle_unknown='ignore', use_cat_names=True)
X_ohe =  ohe.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_ohe, y, test_size=0.3, random_state=42)

# %%
X_ohe.shape
# Out:
# (28648, 2721)

# %% [markdown]
# # Build Model with test/train splits and compare

# %%
# !pip install xgboost
import xgboost

# %%
xgb = xgboost.XGBClassifier()

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
predictions = xgb.predict(X_test)
# Out:
# /home/kaushik/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
prediction_probs = xgb.predict_proba(X_test)

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_curve

# %%
precision_score(y_test, predictions)
# Out:
# 0.6779701209390562

# %%
recall_score(y_test, predictions)
# Out:
# 0.9889311656866137

# %%
prediction_probs = prediction_probs[:,1]

# %%
roc_curve(y_test, prediction_probs)
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99893352, 0.99893352,
#         1.        ]),
#  array([1.72950536e-04, 3.80491180e-03, 4.15081287e-03, ...,
#         9.99827049e-01, 1.00000000e+00, 1.00000000e+00]),
#  array([0.9644627 , 0.94699365, 0.9466981 , ..., 0.3061144 , 0.30504116,
#         0.25386107], dtype=float32))

# %%
import matplotlib.pyplot as plt

# %%
% matplotlib inline

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# Compute fpr, tpr, thresholds and roc auc
fpr, tpr, thresholds = roc_curve(y_test, prediction_probs)
roc_auc = auc(y_test, prediction_probs, reorder=True)

# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)

plt.xlabel('False Positive Rate or (1 - Specifity)')
plt.ylabel('True Positive Rate or (Sensitivity)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")

# %%
auc(y_test, prediction_probs, reorder=True)
# Out:
# 0.6237677931785583

# %% [markdown]
# # Build Model with full data

# %%
xgb.fit(X_ohe,y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
X.columns
# Out:
# Index(['tourney_name', 'surface', 'draw_size', 'tourney_level', 'player1_seed',
#        'player1_entry', 'player1_name', 'player1_hand', 'player1_ht',
#        'player1_ioc', 'player1_age', 'player1_rank', 'player1_rank_points',
#        'player2_seed', 'player2_entry', 'player2_name', 'player2_hand',
#        'player2_ht', 'player2_ioc', 'player2_age', 'player2_rank',
#        'player2_rank_points', 'best_of', 'round'],
#       dtype='object')

# %%
X[X['tourney_name'] == 'Australian Open'].groupby('round').count()
# Out:
#        tourney_name  surface  draw_size  tourney_level  player1_seed  \
# round
# F                10       10         10             10            10
# QF               40       40         40             40            39
# R128            636      636        636            636           315
# R16              80       80         80             80            78
# R32             160      160        160            160           147
# R64             320      320        320            320           270
# SF               20       20         20             20            20
#
#        player1_entry  player1_name  player1_hand  player1_ht  player1_ioc  \
# round
# F                  0            10            10          10           10
# QF                 0            40            40          39           40
# R128              20           636           636         593          636
# R16                0            80            80          79           80
# ...

# %% [markdown]
# # Score each round

# %%
scored = pd.read_csv('/home/kaushik/Downloads/Australian Open Bracket - Semis.csv')

# %%
scored.columns
# Out:
# Index(['tourney_name', 'surface', 'draw_size', 'tourney_level', 'player1_seed',
#        'player1_entry', 'player1_name', 'player1_hand', 'player1_ht',
#        'player1_ioc', 'player1_age', 'player1_rank', 'player1_rank_points',
#        'player2_seed', 'player2_entry', 'player2_name', 'player2_hand',
#        'player2_ht', 'player2_ioc', 'player2_age', 'player2_rank',
#        'player2_rank_points', 'best_of', 'round'],
#       dtype='object')

# %%
scored_higher_ranked_player1 = scored[scored['player1_rank'] < scored['player2_rank']]
scored_lower_ranked_player1 = scored[scored['player1_rank'] > scored['player2_rank']]

# %%
scored_lower_ranked_player1_change = scored_lower_ranked_player1.rename(index=str, columns={'player1_seed':'player2_seed',
                                                                                            'player1_entry':'player2_entry',
                                                                                            'player1_name':'player2_name',
                                                                                            'player1_hand':'player2_hand',
                                                                                            'player1_ht':'player2_ht',
                                                                                            'player1_ioc':'player2_ioc',
                                                                                            'player1_age':'player2_age',
                                                                                            'player1_rank':'player2_rank',
                                                                                            'player1_rank_points':'player2_rank_points',
                                                                                            'player2_seed':'player1_seed',
                                                                                            'player2_entry':'player1_entry',
                                                                                            'player2_name':'player1_name',
                                                                                            'player2_hand':'player1_hand',
                                                                                            'player2_ht':'player1_ht',
                                                                                            'player2_ioc':'player1_ioc',
                                                                                            'player2_age':'player1_age',
                                                                                            'player2_rank':'player1_rank',
                                                                                            'player2_rank_points':'player1_rank_points'})

# %%
scored_lower_ranked_player1_change
# Out:
#       tourney_name surface  draw_size tourney_level  player2_seed  \
# 1  Australian Open    Hard        128             G             3
# 4  Australian Open    Hard        128             G             4
# 5  Australian Open    Hard        128             G             4
# 6  Australian Open    Hard        128             G            27
#
#   player2_entry      player2_name player2_hand  player2_ht player2_ioc  ...    \
# 1           NaN     Roger Federer            R         185         SUI  ...
# 4           NaN  Alexander Zverev            R         198         GER  ...
# 5           NaN  Alexander Zverev            R         198         GER  ...
# 6             Q           Player1            R         183         AUS  ...
#
#    player1_entry   player1_name  player1_hand  player1_ht player1_ioc  \
# 1            NaN   Rafael Nadal             L         185         ESP
# 4            NaN  Roger Federer             R         185         SUI
# ...

# %%
rescored = pd.concat([scored_lower_ranked_player1_change, scored_higher_ranked_player1])
# Out:
# /home/kaushik/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
rescored2 = rescored.reset_index()

# %%
rescored2['index'] = rescored2['index'].astype(int)

# %%
final_scored = rescored2.sort_values('index').reset_index().iloc[:,2:]

# %%
final_scored = final_scored[['tourney_name', 'surface', 'draw_size', 'tourney_level', 'player1_seed',
       'player1_entry', 'player1_name', 'player1_hand', 'player1_ht',
       'player1_ioc', 'player1_age', 'player1_rank', 'player1_rank_points',
       'player2_seed', 'player2_entry', 'player2_name', 'player2_hand',
       'player2_ht', 'player2_ioc', 'player2_age', 'player2_rank',
       'player2_rank_points', 'best_of', 'round']]

# %%
final_scored['draw_size'] = final_scored['draw_size'].astype(float)
final_scored['player1_seed'] = final_scored['player1_seed'].astype(float)
final_scored['player1_entry'] = final_scored['player1_entry'].astype(str)
final_scored['player1_rank'] = final_scored['player1_rank'].astype(float)
final_scored['player1_ht'] = final_scored['player1_ht'].astype(float)
final_scored['player1_age'] = final_scored['player1_age'].astype(float)
final_scored['player1_rank'] = final_scored['player1_rank'].astype(float)
final_scored['player1_rank_points'] = final_scored['player1_rank_points'].astype(float)
final_scored['player2_seed'] = final_scored['player2_seed'].astype(float)
final_scored['player2_entry'] = final_scored['player2_entry'].astype(str)
final_scored['player2_rank'] = final_scored['player2_rank'].astype(float)
final_scored['player2_ht'] = final_scored['player2_ht'].astype(float)
final_scored['player2_age'] = final_scored['player2_age'].astype(float)
final_scored['player2_rank'] = final_scored['player2_rank'].astype(float)
final_scored['player2_rank_points'] = final_scored['player2_rank_points'].astype(float)
final_scored['best_of'] = final_scored['best_of'].astype(float)

# %%
final_scored_ohe =  ohe.transform(final_scored)

# %%
prediction_probs = xgb.predict_proba(final_scored_ohe)

# %%
probs = pd.DataFrame(prediction_probs)

# %%
probs.columns = ['Class0', 'Class1']

# %%
pd.merge(final_scored.reset_index(), probs.reset_index(), how='left', on='index').to_csv('/home/kaushik/Downloads/scored_semis_finals.csv',index=False)
