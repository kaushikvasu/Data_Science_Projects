# %% [markdown]
# # Data
# Kaggle Data: https://www.kaggle.com/mylesoneill/magic-the-gathering-cards

# %%
import pandas as pd

# %% [markdown]
# #### This data has flavor text but is much harder to manage.

# %%
magic_dataset = "../MagicDatasets/AllSets-x_7_17.json"

# %%
magic_cards_sets = pd.read_json(magic_dataset).reset_index()

# %%
magic_cards_sets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Columns: 211 entries, index to pWPN
# dtypes: object(211)
# memory usage: 28.1+ KB

# %%
magic_codes = magic_cards_sets.iloc[4,:]
set_names = magic_cards_sets.iloc[9,:]

# set_dict2 = {magic_codes:set_names}

# %%
magic_cards_sets
# Out:
#                  index                                                10E  \
# 0     alternativeNames                                                NaN
# 1                block                                                NaN
# 2              booster  [rare, uncommon, uncommon, uncommon, common, c...
# 3               border                                              black
# 4                cards  [{u'originalType': u'Creature — Human Cleric',...
# 5                 code                                                10E
# 6         gathererCode                                                NaN
# 7   magicCardsInfoCode                                                10e
# 8   magicRaritiesCodes                                                NaN
# 9               mkm_id                                                 74
# 10            mkm_name                                      Tenth Edition
# 11                name                                      Tenth Edition
# ...

# %%
magic_cards = magic_cards_sets.iloc[4,:]
magic_cards
# Out:
# index                                                cards
# 10E      [{u'originalType': u'Creature — Human Cleric',...
# 2ED      [{u'originalType': u'Summon — Elemental', u'to...
# 3ED      [{u'originalType': u'Summon — Elemental', u'to...
# 4ED      [{u'originalType': u'Summon — Abomination', u'...
# 5DN      [{u'originalType': u'Instant', u'mciNumber': u...
# 5ED      [{u'originalType': u'Summon — Gargoyles', u'to...
# 6ED      [{u'originalType': u'Enchant Creature', u'text...
# 7ED      [{u'originalType': u'Creature — Spirit', u'tou...
# 8ED      [{u'originalType': u'Creature — Angel', u'toug...
# 9ED      [{u'originalType': u'Creature — Angel', u'toug...
# AER      [{u'originalType': u'Enchantment — Aura', u'te...
# AKH      [{u'originalType': u'Creature — Angel', u'toug...
# ALA      [{u'originalType': u'Creature — Human Soldier'...
# ALL      [{u'originalType': u'Artifact Creature', u'tou...
# APC      [{u'originalType': u'Creature — Soldier', u'to...
# ...

# %%
# ATH, CN2, CNS, CON, CPK, CSP, CST, DDE, DDM, DDN, DDP, DDQ, DDR, DGM, DIS, DKM, DPA, DST, EMA, EMN, FRF_UGIN,
# GPT, GTC, H09, ITP, JUD, KLD, MBS, MD1, ME2, ME3, ME4, MED, MGB, MIR, MOR, MPS, NMS, ODY, OGW, PD3, PLS

set_dict = {
    "[10E]" : "Tenth Edition", "[2ED]" : "Unlimited", "[3ED]" : "Revised", "[4ED]" : "Fourth Edition",
    "[5DN]" : "Fifth Dawn", "[5ED]" : "Fifth Edition", "[6ED]" : "Sixth Edition", "[7ED]" : "Seventh Edition",
    "[8ED]" : "Eighth Edition", "[9ED]" : "Ninth Edition", "[ALA]" : "Shards of Alara", "[ALL]" : "Alliances",
    "[APC]" : "Apocalypse", "[ARB]" : "Alara Reborn", "[ARC]" : "Archenemy", "[ARN]" : "Arabian Nights",
    "[ATQ]" : "Aniquities", "[AVR]" : "Avacyn Restored", "[BFZ]" : "Battle for Zendikar", 
    "[BNG]" : "Born of the Gods", "[BOK]" : "Betrayers of Kamigawa", "[BRB]" : "Battle Royale", "[BTB]" : "Beatdown",              "[C13]" : "Commander 2013",
    "[C14]" : "Commander 2014", "[C15]" : "Commander 2015", "[CED]" : "Collectors' Edition",
    "[CEI]" : "International Edition", "[CHK]" : "Champions of Kamigawa", "[CHR]" : "Chronicles",
    "[CM1]" : "Commander's Arsenal", "[CMD]" : "Commander", "[C13]" : "Commander 2013",
    "[DD2]" : "Duel Decks: Jace vs. Chandra", "[DD3_DVD]" : "Duel Decks: Divine vs. Demonic", 
    "[DD3_EVG]" : "Duel Decks: Elves vs. Goblins", "[DD3_GVL]" : "Duel Decks: Garruk vs. Liliana",
    "[DD3_JVC]" : "Duel Decks: Jace vs. Chandra", "[DDC]" : "Duel Decks: Divine vs. Demonic",
    "[DDD]" : "Duel Decks: Garruk vs. Liliana", "[DDF]" : "Duel Decks: Elspeth vs. Tezzeret",
    "[DDG]" : "Duel Decks: Knights vs. Dragons", "[DDH]" : "Duel Deck: Ajani vs. Nicol Bolas",
    "[DDI]" : "Duel Decks: Venser vs. Koth", "[DDJ]" : "Duel Decks: Izzet vs. Golgari", 
    "[DDK]" : "Duel Decks: Sorin vs. Tibalt", "[DDL]" : "Duel Decks: Heroes vs. Monsters",
    "[DDO]" : "Duel Decks: Elspeth vs. Kiora", "[DKA]" : "Dark Ascension", "[FVD]" : "From the Vault: Dragons",
    "[DRK]" : "The Dark", "[DTK]" : "Dragons of Tarkir", "[EVE]" : "Eventide", "[EVG]" : "Duel Decks: Elves vs. Goblins",
    "[EXO]" : "Exodus", "[EXP]" : "Zendikar Expeditions", "[FEM]" : "Fallen Empires", "[FRF]" : "Fate Reforged",
    "[FUT]" : "Future Sight", "[HML]" : "Homelands", "[HOP]" : "Plancechase", "[ICE]" : "Ice Age", "[INV]" : "Invasion",
    "[ISD]" : "Innistrad", "[JOU]" : "Journey into Nyx", "[KTK]" : "Khans of Tarkir", "[LEA]" : "Alpha", 
    "[LEB]" : "Beta", "[LEG]" : "Legends", "[LGN]" : "Legions", "[LRW]" : "Lorwyn", "[M10]" : "Magic 2010", 
    "[M11]" : "Magic 2011", "[M12]" : "Magic 2012", "[M13]" : "Magic 2013", "[M14]" : "Magic 2014", 
    "[M15]" : "Magic 2015", "[MM2]" : "Modern Masters 2015", "[MMA]" : "Modern Masters", "[MMQ]" : "Mercadian Masques",
    "[MRD]" : "Mirrodin", "[NPH]" : "New Phyrexia", "[ONS]" : "Onslaught", "[ORI]" : "Magic Origins", 
    "[PC2]" : "Planarchase 2012", "[PCY]" : "Prophecy"
#     "[KLD]" : "Kaladesh"
}

# %%
cols = ['artist','cmc','colorIdentity','colors','flavor','id','imageName','layout','manaCost'
        'mciNumber','multiverseid','name','number','originalText','originalType','power','printings'
        'rarity','rulings','subtypes','supertypes','text','toughness','type','types','variations']

# %%
main_df = pd.DataFrame(columns=cols)
main_df
# Out:
# Empty DataFrame
# Columns: [artist, cmc, colorIdentity, colors, flavor, id, imageName, layout, manaCostmciNumber, multiverseid, name, number, originalText, originalType, power, printingsrarity, rulings, subtypes, supertypes, text, toughness, type, types, variations]
# Index: []
#
# [0 rows x 24 columns]

# %%
magic_cards
# Out:
# index                                                cards
# 10E      [{u'originalType': u'Creature — Human Cleric',...
# 2ED      [{u'originalType': u'Summon — Elemental', u'to...
# 3ED      [{u'originalType': u'Summon — Elemental', u'to...
# 4ED      [{u'originalType': u'Summon — Abomination', u'...
# 5DN      [{u'originalType': u'Instant', u'mciNumber': u...
# 5ED      [{u'originalType': u'Summon — Gargoyles', u'to...
# 6ED      [{u'originalType': u'Enchant Creature', u'text...
# 7ED      [{u'originalType': u'Creature — Spirit', u'tou...
# 8ED      [{u'originalType': u'Creature — Angel', u'toug...
# 9ED      [{u'originalType': u'Creature — Angel', u'toug...
# AER      [{u'originalType': u'Enchantment — Aura', u'te...
# AKH      [{u'originalType': u'Creature — Angel', u'toug...
# ALA      [{u'originalType': u'Creature — Human Soldier'...
# ALL      [{u'originalType': u'Artifact Creature', u'tou...
# APC      [{u'originalType': u'Creature — Soldier', u'to...
# ...

# %%
for i in range(1,len(magic_cards)):
    set_dict = magic_cards[i]
    for card in set_dict:
        card.pop('foreignNames', None)
        card.pop('legalities', None)
    set_df = pd.DataFrame(set_dict)
    frames = [main_df,set_df]
    main_df = pd.concat(frames)

# %%
main_df = main_df.fillna(" ")
main_df
# Out:
#                            artist border cmc colorIdentity   colors  \
# 0                    Pete Venters          7           [W]  [White]
# 1                     Volkan Baga          5           [W]  [White]
# 2                        Mark Zug          3           [W]  [White]
# 3                      Jim Murray          5           [W]  [White]
# 4                       John Avon          2           [W]  [White]
# 5            D. Alexander Gregory          3           [W]  [White]
# 6                    Justin Sweet          4           [W]  [White]
# 7               Matthew D. Wilson          4           [W]  [White]
# 8                    Rebecca Guay          1           [W]  [White]
# 9                   Rob Alexander          6           [W]  [White]
# 10  Zoltan Boros & Gabor Szikszai          3           [W]  [White]
# 11                Steven Belledin          4           [W]  [White]
# 12                    Daren Bader          1           [W]  [White]
# ...

# %%
main_df.to_csv('../MagicDatasets/MagicCards_7_25.csv',encoding='utf-8')

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b1946ac92492> in <module>()
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
df = pd.read_csv("../magic_app/app/data/MagicCards_7_25.csv")
# Out:
# /Users/KVASU/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print df.iloc[15566,:]
# Out:
# Unnamed: 0                                                         145
# artist                                                   Lius Lasahido
# border
# cmc                                                                5.0
# colorIdentity                                                   [B, R]
# colors                                                    [Black, Red]
# flavor
# hand
# id                            8a20ca25c580a3c123119dcef12ee03add1c291f
# imageName                                             the scorpion god
# layout                                                          normal
# life
# loyalty
# manaCost                                                     {3}{B}{R}
# manaCostmciNumber
# mciNumber                                                          146
# multiverseid                                                  430835.0
# name                                                  The Scorpion God
# names
# ...

# %%
new_df = df.loc[df['name']=="The Scorpion God"]
new_df
# Out:
#        Unnamed: 0              artist border  cmc colorIdentity        colors  \
# 15566         145       Lius Lasahido         5.0        [B, R]  [Black, Red]
# 23266          53  Grzegorz Rutkowski         5.0        [B, R]  [Black, Red]
#
#       flavor hand                                        id         imageName  \
# 15566              8a20ca25c580a3c123119dcef12ee03add1c291f  the scorpion god
# 23266              a41ab9fea4c10772c75b2150dff7576c39852a51  the scorpion god
#
#          ...    starter subtypes   supertypes  \
# 15566    ...               [God]  [Legendary]
# 23266    ...               [God]  [Legendary]
#
#                                                     text timeshifted  \
# 15566  Whenever a creature with a -1/-1 counter on it...
# 23266  Whenever a creature with a -1/-1 counter on it...
#
#       toughness                      type       types variations watermark
# 15566         5  Legendary Creature — God  [Creature]
# ...

# %%
tenth_dict = magic_cards[1]

# %%
tenth_dict

# %%
for card in tenth_dict:
    card.pop('foreignNames', None)
    card.pop('legalities', None)

# %%
tenth_dict

# %%
df = pd.DataFrame(tenth_dict)

# %%
df.info()

# %%
df[pd.isnull(df['text'])]

# %% [markdown]
# #### This data does not have flavor text.

# %%
magic_cards = pd.read_json("Magic Datasets/AllCards-x.json").transpose().reset_index()

# %%
magic_sets = pd.read_json("Magic Datasets/AllSets-x.json").transpose().reset_index()

# %%
magic_cards

# %%
card_akroma = magic_cards.loc[magic_cards['index']=='Akroma, Angel of Wrath'].transpose()
card_akroma = card_akroma.reset_index()
card_akroma

# %%
magic_cards.info()

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# - Create clustering models to cluster the card data.
# - Figure out what are the key features/words.
# - If given a card, output 5 "nearest" cards.

# %% [markdown]
# #### Models
# - Create a model only on "rules" text
# - Create a model only on "flavor" text
# - Create a model using all features

# %% [markdown]
# #### "Rules" Model

# %%
magic_rules_only = magic_cards[['name','text']]

# %%
magic_rules_only

# %% [markdown]
# # Supervised Learning
# - Create models on features I select. Some sort of nearest neighbor models.

# %% [markdown]
# # Web Application
# - Have drop down features that user can choose from.
# - Lists cards that have those features.
# - "Click" on chosen card.
# - Outputs chosen card + 5 "nearest" cards.
